# %%
# TASK:
# - forward_td_lambda, lambda_value ~ (variance, convergence)
#
# PROCESS:
# - run the same BATCH*EPISODES for different lambda_value [0.0, 1.0] twice
# - forward_td_lambda_learning_offline
# - check target_state_value_store
#   accuracy history over different lambda_value
#   final_accuracy over different lambda_value
#
# RESULTS:
# - the same lambda_value can have very different final_accuracy in two runs
# - not stable, but smaller lambda_value seems having better final_accuracy
# - different lambda_value shows no obvious with variance in two runs
#
# INTERPRETATION:
# - sampling variance (sequence length) affects how well td(lambda) combines
#   estimated remaining value (td_return) vs using real final sample reward
# - forward TD(0) is equivalent to one-step lookahead
# - forward TD(1) is equivalent to MC learning
# - TD(0) is expected to decrease the variance in the accuracy history
#   the effect is probably more obvious when episodes are from convergence
#   less obvious when number of episodes is large
#
# RUN:
# %%
import sys

sys.path.append("../")

from numpy import arange
from tqdm import tqdm

from src.module.model_free_agent import ModelFreeAgent

from src.easy_21.game import playout, ACTIONS


#
# hyperparameters and agent config
#

BATCH = 10
EPISODES = int(1e5)

PLAYER = ModelFreeAgent("player", ACTIONS)
PLAYER.load_optimal_state_values()

PLAYER.target_state_value_store.metrics.register(
    "accuracy",
    PLAYER.target_state_value_store_accuracy_to_optimal,
)
PLAYER.target_state_value_store.metrics.register(
    "final_accuracy",
    PLAYER.target_state_value_store_accuracy_to_optimal,
)

#
# process
#


lambda_value_range = arange(0, 1.1, 0.2)

for _ in range(2):
    for lambda_value in tqdm(lambda_value_range):

        PLAYER.action_value_store.reset()

        for _ in range(BATCH):
            for _ in range(EPISODES):
                playout(
                    player_policy=PLAYER.e_greedy_policy,
                    player_offline_learning=lambda episode: PLAYER.forward_td_lambda_learning_offline(
                        episode, lambda_value=lambda_value
                    ),
                )

            PLAYER.target_state_value_store.metrics.record("accuracy")

        PLAYER.target_state_value_store.metrics.stack("accuracy")
        PLAYER.target_state_value_store.record("final_accuracy")

    PLAYER.target_state_value_store.metrics.stack("final_accuracy")

PLAYER.target_state_value_store.metrics.plot_history_stack(
    "final_accuracy", x=lambda_value_range
)
PLAYER.target_state_value_store.metrics.plot_history_stack(
    "accuracy",
    labels=[f"{r:.1f}" for r in [*lambda_value_range, *lambda_value_range]],
)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# player_target_state_values_accuracy: 0.0652
# player_target_state_values_accuracy: 0.0480
# player_target_state_values_accuracy: 0.0421
# player_target_state_values_accuracy: 0.0350
# player_target_state_values_accuracy: 0.0302
# player_target_state_values_accuracy: 0.0282
# player_target_state_values_accuracy: 0.0258
# player_target_state_values_accuracy: 0.0235
# player_target_state_values_accuracy: 0.0224
#  17%|█▋        | 1/6 [00:22<01:52, 22.55s/it]
# player_target_state_values_accuracy: 0.0210
# player_target_state_values_final_accuracy: 0.0210
# player_target_state_values_accuracy: 0.0634
# player_target_state_values_accuracy: 0.0466
# player_target_state_values_accuracy: 0.0355
# player_target_state_values_accuracy: 0.0308
# player_target_state_values_accuracy: 0.0284
# player_target_state_values_accuracy: 0.0265
# player_target_state_values_accuracy: 0.0248
# player_target_state_values_accuracy: 0.0226
# player_target_state_values_accuracy: 0.0218
#  33%|███▎      | 2/6 [00:45<01:30, 22.72s/it]
# player_target_state_values_accuracy: 0.0196
# player_target_state_values_final_accuracy: 0.0196
# player_target_state_values_accuracy: 0.0529
# player_target_state_values_accuracy: 0.0402
# player_target_state_values_accuracy: 0.0329
# player_target_state_values_accuracy: 0.0293
# player_target_state_values_accuracy: 0.0273
# player_target_state_values_accuracy: 0.0260
# player_target_state_values_accuracy: 0.0240
# player_target_state_values_accuracy: 0.0226
# player_target_state_values_accuracy: 0.0205
#  50%|█████     | 3/6 [01:10<01:09, 23.21s/it]
# player_target_state_values_accuracy: 0.0194
# player_target_state_values_final_accuracy: 0.0194
# player_target_state_values_accuracy: 0.0563
# player_target_state_values_accuracy: 0.0406
# player_target_state_values_accuracy: 0.0347
# player_target_state_values_accuracy: 0.0316
# player_target_state_values_accuracy: 0.0276
# player_target_state_values_accuracy: 0.0257
# player_target_state_values_accuracy: 0.0236
# player_target_state_values_accuracy: 0.0215
# player_target_state_values_accuracy: 0.0212
#  67%|██████▋   | 4/6 [01:34<00:47, 23.59s/it]
# player_target_state_values_accuracy: 0.0204
# player_target_state_values_final_accuracy: 0.0204
# player_target_state_values_accuracy: 0.0660
# player_target_state_values_accuracy: 0.0436
# player_target_state_values_accuracy: 0.0349
# player_target_state_values_accuracy: 0.0312
# player_target_state_values_accuracy: 0.0299
# player_target_state_values_accuracy: 0.0282
# player_target_state_values_accuracy: 0.0270
# player_target_state_values_accuracy: 0.0267
# player_target_state_values_accuracy: 0.0225
#  83%|████████▎ | 5/6 [01:58<00:23, 23.57s/it]
# player_target_state_values_accuracy: 0.0215
# player_target_state_values_final_accuracy: 0.0215
# player_target_state_values_accuracy: 0.0611
# player_target_state_values_accuracy: 0.0457
# player_target_state_values_accuracy: 0.0410
# player_target_state_values_accuracy: 0.0340
# player_target_state_values_accuracy: 0.0320
# player_target_state_values_accuracy: 0.0277
# player_target_state_values_accuracy: 0.0270
# player_target_state_values_accuracy: 0.0264
# player_target_state_values_accuracy: 0.0264
# 100%|██████████| 6/6 [02:21<00:00, 23.59s/it]
#   0%|          | 0/6 [00:00<?, ?it/s]
# player_target_state_values_accuracy: 0.0247
# player_target_state_values_final_accuracy: 0.0247
# player_target_state_values_accuracy: 0.0596
# player_target_state_values_accuracy: 0.0422
# player_target_state_values_accuracy: 0.0365
# player_target_state_values_accuracy: 0.0324
# player_target_state_values_accuracy: 0.0277
# player_target_state_values_accuracy: 0.0260
# player_target_state_values_accuracy: 0.0248
# player_target_state_values_accuracy: 0.0240
# player_target_state_values_accuracy: 0.0232
#  17%|█▋        | 1/6 [00:22<01:52, 22.46s/it]
# player_target_state_values_accuracy: 0.0220
# player_target_state_values_final_accuracy: 0.0220
# player_target_state_values_accuracy: 0.0625
# player_target_state_values_accuracy: 0.0468
# player_target_state_values_accuracy: 0.0369
# player_target_state_values_accuracy: 0.0305
# player_target_state_values_accuracy: 0.0285
# player_target_state_values_accuracy: 0.0256
# player_target_state_values_accuracy: 0.0239
# player_target_state_values_accuracy: 0.0222
# player_target_state_values_accuracy: 0.0215
#  33%|███▎      | 2/6 [00:45<01:30, 22.67s/it]
# player_target_state_values_accuracy: 0.0200
# player_target_state_values_final_accuracy: 0.0200
# player_target_state_values_accuracy: 0.0590
# player_target_state_values_accuracy: 0.0420
# player_target_state_values_accuracy: 0.0351
# player_target_state_values_accuracy: 0.0308
# player_target_state_values_accuracy: 0.0282
# player_target_state_values_accuracy: 0.0261
# player_target_state_values_accuracy: 0.0238
# player_target_state_values_accuracy: 0.0212
# player_target_state_values_accuracy: 0.0200
#  50%|█████     | 3/6 [01:08<01:07, 22.65s/it]
# player_target_state_values_accuracy: 0.0180
# player_target_state_values_final_accuracy: 0.0180
# player_target_state_values_accuracy: 0.0636
# player_target_state_values_accuracy: 0.0495
# player_target_state_values_accuracy: 0.0394
# player_target_state_values_accuracy: 0.0348
# player_target_state_values_accuracy: 0.0312
# player_target_state_values_accuracy: 0.0281
# player_target_state_values_accuracy: 0.0261
# player_target_state_values_accuracy: 0.0243
# player_target_state_values_accuracy: 0.0219
#  67%|██████▋   | 4/6 [01:33<00:46, 23.48s/it]
# player_target_state_values_accuracy: 0.0214
# player_target_state_values_final_accuracy: 0.0214
# player_target_state_values_accuracy: 0.0577
# player_target_state_values_accuracy: 0.0423
# player_target_state_values_accuracy: 0.0354
# player_target_state_values_accuracy: 0.0306
# player_target_state_values_accuracy: 0.0280
# player_target_state_values_accuracy: 0.0247
# player_target_state_values_accuracy: 0.0217
# player_target_state_values_accuracy: 0.0216
# player_target_state_values_accuracy: 0.0202
#  83%|████████▎ | 5/6 [01:57<00:23, 23.59s/it]
# player_target_state_values_accuracy: 0.0198
# player_target_state_values_final_accuracy: 0.0198
# player_target_state_values_accuracy: 0.0700
# player_target_state_values_accuracy: 0.0509
# player_target_state_values_accuracy: 0.0403
# player_target_state_values_accuracy: 0.0354
# player_target_state_values_accuracy: 0.0323
# player_target_state_values_accuracy: 0.0279
# player_target_state_values_accuracy: 0.0262
# player_target_state_values_accuracy: 0.0238
# player_target_state_values_accuracy: 0.0221
# 100%|██████████| 6/6 [02:20<00:00, 23.46s/it]
# player_target_state_values_accuracy: 0.0212
# player_target_state_values_final_accuracy: 0.0212
